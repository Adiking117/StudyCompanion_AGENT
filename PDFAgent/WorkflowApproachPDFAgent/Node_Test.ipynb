# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()
chat_model=ChatGroq(model="llama3-8b-8192")

# %%
from langchain_community.document_loaders import PyPDFLoader
import os
from langchain_core.tools import tool

def load_pdf(pdfpath: str) -> list:
    """Load pdf at a particular path(only once per file)."""

    if not os.path.exists(pdfpath):
        raise FileNotFoundError(f"PDF file '{pdfpath}' not found.")

    loader = PyPDFLoader(pdfpath)
    pdf = loader.load()
    return pdf

# %%
pdf = load_pdf("sp.pdf")
pdf
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 0, 'page_label': '1'}, page_content='Master Spring & Spring Boot\nwith Hibernate & React\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Top frameworks in the Java world today\nSpring Framework\nSpring Boot\nBeginners find the first steps very diﬀicult:\nLot of terminology: Dependency Injection, IOC, Auto\nwiring, Auto configuration, Starter Projects ..\nVariety of applications: Web app, REST API, Full Stack\nVariety of other framework, tool and platform\nintegrations: Maven, Gradle, Spring Data, JPA, Hibernate,\nDocker and Cloud\nGetting Started\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content="We've created a simple path focusing on the\nFundamentals\nUsing a Hands-on Approach\nYou will build more than 10 Maven and Gradle\nprojects during this course!\nThis course is designed for absolute beginners to\nSpring & Spring Boot\nOur Goal : Help you start your journey with Spring &\nSpring Boot\nSimple Path - Learn Spring & Spring Boot & ...\n3"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 3, 'page_label': '4'}, page_content='Learning Spring & Spring Boot\ncan be tricky:\nLots of new terminology, tools and\nframeworks\nAs time passes, we forget things\nHow do you improve your\nchances of remembering\nthings?\nActive learning - think & make notes\nReview the presentation once in a\nwhile\nHow do you put your best foot forward?\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 4, 'page_label': '5'}, page_content='Videos with:\nPresentations &\nDemos where we build projects\nQuizzes:\nTo Reinforce Concepts\n(Recommended) Take your\ntime. Do not hesitate to\nreplay videos!\n(Recommended) Have Fun!\nOur Approach\n5'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 5, 'page_label': '6'}, page_content='6'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 6, 'page_label': '7'}, page_content='Spring Framework\n7'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='You can build a variety of applications using\nJava, Spring and Spring Boot:\nWeb\nREST API\nFull Stack\nMicroservices\nIrrespective of the app you are building:\nSpring framework provides all the core features\nUnderstanding Spring helps you learn Spring Boot easily\nHelps in debugging problems quickly\nIn this module, we focus extensively on Spring\nFramework\nGetting Started with Spring Framework - Why?\n8'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='Goal: Understand core features of Spring Framework\nApproach: Build a Loose Coupled Hello World Gaming\nApp with Modern Spring Approach\nGet Hands-on with Spring and understand:\nWhy Spring?\nTerminology\nTight Coupling and Loose Coupling\nIOC Container\nApplication Context\nComponent Scan\nDependency Injection\nSpring Beans\nAuto Wiring\nGetting Started with Spring Framework - Goals\n9'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Design Game Runner to run games (Mario, SuperContra,\nPacman etc) in an iterative approach:\nIteration 1: Tightly Coupled Java Code\nGameRunner class\nGame classes: Mario, SuperContra, Pacman etc\nIteration 2: Loose Coupling - Interfaces\nGameRunner class\nGamingConsole interface\nGame classes: Mario, SuperContra, Pacman etc\nIteration 3: Loose Coupling - Spring Level 1\nSpring Beans\nSpring framework will manage objects and wiring\nIteration 4: Loose Coupling - Spring Level 2\nSpring Annotations\nSpring framework will create, manage & auto-wire objects\n...\nGetting Started with Spring Framework - Approach\n10'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='Very Few Spring Framework users understand\nfundamentals:\nSpring Container vs Spring Context vs IOC Container vs\nApplication Context\nJava Bean vs Spring Bean\nAuto Wiring vs Dependency Injection\nHow can you build loosely coupled applications?\nMaking good use of Java Interfaces along with Spring\nWe spent multiple weeks designing this section to\nhelp you understand these fundamentals\nThis is the most important section of the course:\nFocus really well to understand the fundamentals\nGood luck!\nDo you want to do well at interviews?\n1 1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='Local Variable Type Inference\nJava compiler infers the type of the variable at compile time\nIntroduced in Java 10\nYou can add final if you want\nvar can also be used in loops\nRemember:\nYou cannot assign null\nvar is NOT a keyword\nCANNOT be used for member variables, method parameters or return types\nBest Practices:\nGood variable names\nMinimizeScope\n// List<String> numbers = new ArrayList<>(list);var numbers = new ArrayList<>(list);\n12'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content="Coupling: How much work is involved in changing something?\nCoupling is important everywhere:\nAn engine is tightly coupled to a Car\nA wheel is loosely coupled to a Car\nYou can take a laptop anywhere you go\nA computer, on the other hand, is a little bit more diﬀicult to move\nCoupling is even more important in building great so\x00ware\nOnly thing constant in technology is change\nBusiness requirements change\nFrameworks change\nCode changes\nWe want Loose Coupling as much as possible\nWe want to make functional changes with as less code changes as possible\nLet's explore how Java Interfaces and Spring Framework help\nwith Loose Coupling!\nWhy is Coupling Important?\n13"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content="Question 1: Spring Container vs Spring Context vs IOC\nContainer vs Application Context\nQuestion 2: Java Bean vs Spring Bean\nQuestion 3: How can I list all beans managed by\nSpring Framework?\nQuestion 4: What if multiple matching beans are\navailable?\nQuestion 5: Spring is managing objects and\nperforming auto-wiring.\nBUT aren't we writing the code to create objects?\nHow do we get Spring to create objects for us?\nQuestion 6: Is Spring really making things easy?\nSpring Questions You Might Be Thinking About\n14"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='Spring Container: Manages Spring beans &\ntheir lifecycle\n1: Bean Factory: Basic Spring Container\n2: Application Context: Advanced Spring\nContainer with enterprise-specific features\nEasy to use in web applications\nEasy internationalization\nEasy integration with Spring AOP\nWhich one to use?: Most enterprise\napplications use Application Context\nRecommended for web applications, web services -\nREST API and microservices\nWhat is Spring Container?\n15'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='Java Bean: Classes adhering to 3 constraints:\n1: Have public default (no argument) constructors\n2: Allow access to their properties using getter and\nsetter methods\n3: Implement java.io.Serializable\nPOJO: Plain Old Java Object\nNo constraints\nAny Java Object is a POJO!\nSpring Bean: Any Java object that is managed\nby Spring\nSpring uses IOC Container (Bean Factory or\nApplication Context) to manage these objects\nExploring Java Bean vs POJO vs Spring Bean\n16'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Constructor-based : Dependencies are set\nby creating the Bean using its Constructor\nSetter-based : Dependencies are set by\ncalling setter methods on your beans\nField: No setter or constructor.\nDependency is injected using reflection.\nQuestion: Which one should you use?\nSpring team recommends Constructor-based\ninjection as dependencies are automatically set\nwhen an object is created!\nExploring Spring - Dependency Injection Types\n17'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='When a dependency needs to be @Autowired, IOC container\nlooks for matches/candidates (by name and/or type)\n1: If no match is found\nResult: Exception is thrown\nYou need to help Spring Framework find a match\nTypical problems:\n@Component (or ..) missing\nClass not in component scan\n2: One match is found\nResult: Autowiring is successful\n3: Multiple candidates\nResult: Exception is thrown\nYou need to help Spring Framework choose between the candidates\n1: Mark one of them as @Primary\nIf only one of the candidates is marked @Primary, it becomes the auto-wired value\n2: Use @Qualifier - Example: @Qualifier("myQualifierName")\nProvides more specific control\nCan be used on a class, member variables and method parameters\nExploring auto-wiring in depth\n18'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Primary vs @Qualifier - Which one to use?\n@Primary - A bean should be given preference when multiple candidates are qualified\n@Qualifier - A specific bean should be auto-wired (name of the bean can be used as qualifier)\nALWAYS think from the perspective of the class using the SortingAlgorithm:\n1: Just @Autowired: Give me (preferred) SortingAlgorithm\n2: @Autowired + @Qualifier: I only want to use specific SortingAlgorithm - RadixSort\n(REMEMBER) @Qualifier has higher priority then @Primary\n@Component @Primaryclass QuickSort implement SortingAlgorithm {}\n@Componentclass BubbleSort implement SortingAlgorithm {}\n@Component @Qualifier("RadixSortQualifier")class RadixSort implement SortingAlgorithm {}\n@Componentclass ComplexAlgorithm    @Autowired     private SortingAlgorithm algorithm;\n@Componentclass AnotherComplexAlgorithm    @Autowired @Qualifier("RadixSortQualifier")     private SortingAlgorithm iWantToUseRadixSortOnly;\n19'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='@Component (..): An instance of class will be managed by\nSpring framework\nDependency: GameRunner needs GamingConsole impl!\nGamingConsole Impl (Ex: MarioGame) is a dependency of GameRunner\nComponent Scan: How does Spring Framework find\ncomponent classes?\nIt scans packages! (@ComponentScan("com.in28minutes"))\nDependency Injection: Identify beans, their dependencies\nand wire them together (provides IOC - Inversion of Control)\nSpring Beans: An object managed by Spring Framework\nIoC container: Manages the lifecycle of beans and dependencies\nTypes: ApplicationContext (complex), BeanFactory (simpler features - rarely used)\nAutowiring: Process of wiring in dependencies for a Spring Bean\nSpring Framework - Important Terminology\n20'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='@Component vs @Bean\nHeading @Component @Bean\nWhere? Can be used on any Java class Typically used on methods in Spring\nConfiguration classes\nEase of use Very easy. Just add an annotation. You write all the code.\nAutowiring Yes - Field, Setter or Constructor Injection Yes - method call or method parameters\nWho creates\nbeans?\nSpring Framework You write bean creation code\nRecommended\nFor\nInstantiating Beans for Your Own Application\nCode: @Component\n1:Custom Business Logic\n2: Instantiating Beans for 3rd-party\nlibraries: @Bean\nBeans per class? One (Singleton) or Many (Prototype) One or Many - You can create as many as\nyou want\n21'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='-\nIn Game Runner Hello World App, we have very few classes\nBUT Real World applications are much more complex:\nMultiple Layers (Web, Business, Data etc)\nEach layer is dependent on the layer below it!\nExample: Business Layer class talks to a Data Layer class\nData Layer class is a dependency of Business Layer class\nThere are thousands of such dependencies in every application!\nWith Spring Framework:\nINSTEAD of FOCUSING on objects, their dependencies and wiring\nYou can focus on the business logic of your application!\nSpring Framework manages the lifecycle of objects:\nMark components using annotations: @Component (and others..)\nMark dependencies using @Autowired\nAllow Spring Framework to do its magic!\nEx: BusinessCalculationService\nWhy do we have a lot of Dependencies?\n22'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='Create classes and interfaces as needed\nUse constructor injection to inject dependencies\nMake MongoDbDataService as primary\nCreate a Spring Context\nPrefer annotations\nRetrieve BusinessCalculationService bean and run findMax method\nExercise - BusinessCalculationService\npublic interface DataService    int[] retrieveData();\npublic class MongoDbDataService implements DataService    public int[] retrieveData()        return new int[] { 11, 22, 33, 44, 55 };\npublic class MySQLDataService implements DataService\n    public int[] retrieveData()        return new int[] { 1, 2, 3, 4, 5 };\npublic class BusinessCalculationService        public int findMax()        return Arrays.stream(dataService.retrieveData())\n                                    .max().orElse(0);\n23'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 23, 'page_label': '24'}, page_content='Default initialization for Spring Beans: Eager\nEager initialization is recommended:\nErrors in the configuration are discovered immediately at\napplication startup\nHowever, you can configure beans to be lazily initialized\nusing Lazy annotation:\nNOT recommended (AND) Not frequently used\nLazy annotation:\nCan be used almost everywhere @Component and @Bean are used\nLazy-resolution proxy will be injected instead of actual dependency\nCan be used on Configuration (@Configuration) class:\nAll @Bean methods within the @Configuration will be lazily initialized\nExploring Lazy Initialization of Spring Beans\n24'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 24, 'page_label': '25'}, page_content='Comparing Lazy Initialization vs Eager Initialization\nHeading Lazy Initialization Eager Initialization\nInitialization time Bean initialized when it is first made use\nof in the application\nBean initialized at startup of the\napplication\nDefault NOT Default Default\nCode Snippet @Lazy OR @Lazy(value=true) @Lazy(value=false) OR (Absence\nof @Lazy)\nWhat happens if there are\nerrors in initializing?\nErrors will result in runtime exceptions Errors will prevent application\nfrom starting up\nUsage Rarely used Very frequently used\nMemory Consumption Less (until bean is initialized) All beans are initialized at startup\nRecommended Scenario Beans very rarely used in your app Most of your beans\n25'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 25, 'page_label': '26'}, page_content='Spring Beans are defined to be used in a specific scope:\nSingleton - One object instance per Spring IoC container\nPrototype - Possibly many object instances per Spring IoC\ncontainer\nScopes applicable ONLY for web-aware Spring ApplicationContext\nRequest - One object instance per single HTTP request\nSession - One object instance per user HTTP Session\nApplication - One object instance per web application runtime\nWebsocket - One object instance per WebSocket instance\nJava Singleton (GOF) vs Spring Singleton\nSpring Singleton: One object instance per Spring IoC container\nJava Singleton (GOF): One object instance per JVM\nSpring Bean Scopes\n26'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 26, 'page_label': '27'}, page_content='Prototype vs Singleton Bean Scope\nHeading Prototype Singleton\nInstances Possibly Many per Spring IOC Container One per Spring IOC Container\nBeans New bean instance created every time the\nbean is referred to\nSame bean instance reused\nDefault NOT Default Default\nCode Snippet @Scope(value=\nConfigurableBeanFactory.SCOPE_PROTOTYPE)\n@Scope(value=\nConfigurableBeanFactory.SCOPE_SINGLETON)\nOR Default\nUsage Rarely used Very frequently used\nRecommended\nScenario\nStateful beans Stateless beans\n27'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 27, 'page_label': '28'}, page_content="Enterprise capabilities were initially built into JDK\nWith time, they were separated out:\nJ2EE - Java 2 Platform Enterprise Edition\nJava EE - Java Platform Enterprise Edition (Rebranding)\nJakarta EE (Oracle gave Java EE rights to the Eclipse\nFoundation)\nImportant Specifications:\nJakarta Server Pages (JSP)\nJakarta Standard Tag Library (JSTL)\nJakarta Enterprise Beans (EJB)\nJakarta RESTful Web Services (JAX-RS)\nJakarta Bean Validation\nJakarta Contexts and Dependency Injection (CDI)\nJakarta Persistence (JPA)\nSupported by Spring 6 and Spring Boot 3\nThat's why we use jakarta. packages (instead of javax.)\nEvolution of Jakarta EE: vs J2EE vs Java EE\n28"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 28, 'page_label': '29'}, page_content='Spring Framework V1 was released in 2004\nCDI specification introduced into Java EE 6 platform in\nDecember 2009\nNow called Jakarta Contexts and Dependency Injection (CDI)\nCDI is a specification (interface)\nSpring Framework implements CDI\nImportant Inject API Annotations:\nInject (~Autowired in Spring)\nNamed (~Component in Spring)\nQualifier\nScope\nSingleton\nJakarta Contexts & Dependency Injection (CDI)\n29'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 29, 'page_label': '30'}, page_content="Let's Compare: Annotations vs XML Configuration\nHeading Annotations XML Configuration\nEase of use Very Easy (defined close to source - class, method and/or\nvariable)\nCumbersome\nShort and concise Yes No\nClean POJOs No. POJOs are polluted with Spring Annotations Yes. No change in Java\ncode.\nEasy to Maintain Yes No\nUsage Frequency Almost all recent projects Rarely\nRecommendation Either of them is fine BUT be consistent Do NOT mix both\nDebugging\ndiﬀiculty\nHard Medium\n30"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 30, 'page_label': '31'}, page_content='@Component - Generic annotation applicable for any class\nBase for all Spring Stereotype Annotations\nSpecializations of @Component:\n@Service - Indicates that an annotated class has business logic\n@Controller - Indicates that an annotated class is a "Controller" (e.g. a web controller)\nUsed to define controllers in your web applications and REST API\n@Repository - Indicates that an annotated class is used to retrieve and/or manipulate\ndata in a database\nWhat should you use?\n(MY RECOMMENDATION) Use the most specific annotation possible\nWhy?\nBy using a specific annotation, you are giving more information to the framework about\nyour intentions.\nYou can use AOP at a later point to add additional behavior\nExample: For @Repository, Spring automatically wires in JDBC Exception translation features\nSpring Stereotype Annotations - @Component & more..\n31'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 31, 'page_label': '32'}, page_content='Quick Review of Important Spring Annotations\nAnnotation Description\n@Configuration Indicates that a class declares one or more @Bean methods and may be processed by the\nSpring container to generate bean definitions\n@ComponentScan Define specific packages to scan for components. If specific packages are not defined,\nscanning will occur from the package of the class that declares this annotation\n@Bean Indicates that a method produces a bean to be managed by the Spring container\n@Component Indicates that an annotated class is a "component"\n@Service Specialization of @Component indicating that an annotated class has business logic\n@Controller Specialization of @Component indicating that an annotated class is a "Controller" (e.g. a\nweb controller). Used to define controllers in your web applications and REST API\n@Repository Specialization of @Component indicating that an annotated class is used to retrieve\nand/or manipulate data in a database\n32'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 32, 'page_label': '33'}, page_content='Quick Review of Important Spring Annotations - 2\nAnnotation Description\n@Primary Indicates that a bean should be given preference when\nmultiple candidates are qualified to autowire a single-\nvalued dependency\n@Qualifier Used on a field or parameter as a qualifier for\ncandidate beans when autowiring\n@Lazy Indicates that a bean has to be lazily initialized.\nAbsence of @Lazy annotation will lead to eager\ninitialization.\n@Scope (value =\nConfigurableBeanFactory.SCOPE_PROTOTYPE)\nDefines a bean to be a prototype - a new instance will\nbe created every time you refer to the bean. Default\nscope is singleton - one instance per IOC container.\n33'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 33, 'page_label': '34'}, page_content='Quick Review of Important Spring Annotations - 3\nAnnotation Description\n@PostConstruct Identifies the method that will be executed a\x00er dependency injection is done to perform\nany initialization\n@PreDestroy Identifies the method that will receive the callback notification to signal that the instance is\nin the process of being removed by the container. Typically used to release resources that it\nhas been holding.\n@Named Jakarta Contexts & Dependency Injection (CDI) Annotation similar to Component\n@Inject Jakarta Contexts & Dependency Injection (CDI) Annotation similar to Autowired\n34'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 34, 'page_label': '35'}, page_content='Quick Review of Important Spring Concepts\nConcept Description\nDependency\nInjection\nIdentify beans, their dependencies and wire them together (provides IOC - Inversion of\nControl)\nConstr. injection Dependencies are set by creating the Bean using its Constructor\nSetter injection Dependencies are set by calling setter methods on your beans\nField injection No setter or constructor. Dependency is injected using reflection.\nIOC Container Spring IOC Context that manages Spring beans & their lifecycle\nBean Factory Basic Spring IOC Container\nApplication\nContext\nAdvanced Spring IOC Container with enterprise-specific features - Easy to use in web\napplications with internationalization features and good integration with Spring AOP\nSpring Beans Objects managed by Spring\nAuto-wiring Process of wiring in dependencies for a Spring Bean\n35'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 35, 'page_label': '36'}, page_content="Spring Core : IOC Container, Dependency\nInjection, Auto Wiring, ..\nThese are the fundamental building blocks to:\nBuilding web applications\nCreating REST API\nImplementing authentication and authorization\nTalking to a database\nIntegrating with other systems\nWriting great unit tests\nLet's now get a Spring Big Picture:\nSpring Framework\nSpring Modules\nSpring Projects\nSpring Big Picture - Framework, Modules and Projects\n36"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 36, 'page_label': '37'}, page_content='Spring Framework contains multiple Spring Modules:\nFundamental Features: Core (IOC Container, Dependency\nInjection, Auto Wiring, ..)\nWeb: Spring MVC etc (Web applications, REST API)\nWeb Reactive: Spring WebFlux etc\nData Access: JDBC, JPA etc\nIntegration: JMS etc\nTesting: Mock Objects, Spring MVC Test etc\nNo Dumb Question: Why is Spring Framework divided\ninto Modules?\nEach application can choose modules they want to make use of\nThey do not need to make use of everything in Spring\nframework!\nSpring Big Picture - Framework and Modules\n37'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 37, 'page_label': '38'}, page_content='Application architectures evolve continuously\nWeb > REST API > Microservices > Cloud > ...\nSpring evolves through Spring Projects:\nFirst Project: Spring Framework\nSpring Security: Secure your web application or REST API\nor microservice\nSpring Data: Integrate the same way with diﬀerent types\nof databases : NoSQL and Relational\nSpring Integration: Address challenges with integration\nwith other applications\nSpring Boot: Popular framework to build microservices\nSpring Cloud: Build cloud native applications\nSpring Big Picture - Spring Projects\n38'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 38, 'page_label': '39'}, page_content="Hierarchy: Spring Projects > Spring Framework >\nSpring Modules\nWhy is Spring Eco system popular?\nLoose Coupling: Spring manages creation and wiring of beans\nand dependencies\nMakes it easy to build loosely coupled applications\nMake writing unit tests easy! (Spring Unit Testing)\nReduced Boilerplate Code: Focus on Business Logic\nExample: No need for exception handling in each method!\nAll Checked Exceptions are converted to Runtime or Unchecked Exceptions\nArchitectural Flexibility: Spring Modules and Projects\nYou can pick and choose which ones to use (You DON'T need to use all of\nthem!)\nEvolution with Time: Microservices and Cloud\nSpring Boot, Spring Cloud etc!\nSpring Big Picture - Framework, Modules and Projects\n39"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 39, 'page_label': '40'}, page_content='Spring Boot\nin 10(ish) Steps\n40'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 40, 'page_label': '41'}, page_content='WHY Spring Boot?\nYou can build web apps & REST API WITHOUT Spring\nBoot\nWhat is the need for Spring Boot?\nWHAT are the goals of Spring Boot?\nHOW does Spring Boot work?\nCOMPARE Spring Boot vs Spring MVC vs\nSpring\nGetting Started with Spring Boot\n41'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 41, 'page_label': '42'}, page_content='1: Understand the world before Spring Boot (10000 Feet)\n2: Create a Spring Boot Project\n3: Build a simple REST API using Spring Boot\n4: Understand the MAGIC of Spring Boot\nSpring Initializr\nStarter Projects\nAuto Configuration\nDeveloper Tools\nActuator\n...\nGetting Started with Spring Boot - Approach\n42'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 42, 'page_label': '43'}, page_content='Setting up Spring Projects before Spring\nBoot was NOT easy!\nWe needed to configure a lot of things\nbefore we have a production-ready\napplication\nWorld Before Spring Boot!\n43'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 43, 'page_label': '44'}, page_content='World Before Spring Boot - 1 - Dependency Management\nManage frameworks and versions\nREST API - Spring framework, Spring MVC framework, JSON binding framework, ..\nUnit Tests - Spring Test, Mockito, JUnit, ...\n<dependency>    <groupId>org.springframework</groupId>    <artifactId>spring-webmvc</artifactId>    <version>6.2.2.RELEASE</version></dependency><dependency>    <groupId>com.fasterxml.jackson.core</groupId>    <artifactId>jackson-databind</artifactId>    <version>2.13.3</version></dependency><dependency>    <groupId>log4j</groupId>    <artifactId>log4j</artifactId>    <version>1.2.17</version></dependency>\n44'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 44, 'page_label': '45'}, page_content='World Before Spring Boot - 2 - web.xml\nExample: Configure DispatcherServlet for Spring MVC\n<servlet>    <servlet-name>dispatcher</servlet-name>    <servlet-class>        org.springframework.web.servlet.DispatcherServlet    </servlet-class>    <init-param>        <param-name>contextConfigLocation</param-name>        <param-value>/WEB-INF/todo-servlet.xml</param-value>    </init-param>    <load-on-startup>1</load-on-startup></servlet>\n<servlet-mapping>    <servlet-name>dispatcher</servlet-name>    <url-pattern>/*</url-pattern></servlet-mapping>\n45'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 45, 'page_label': '46'}, page_content='World Before Spring Boot - 3 - Spring Configuration\nDefine your Spring Configuration\nComponent Scan\nView Resolver\n....\n<context:component-scan base-package="com.in28minutes" />\n<bean    class="org.springframework.web.servlet.view.InternalResourceViewResolver">    <property name="prefix">        <value>/WEB-INF/views/</value>    </property>    <property name="suffix">        <value>.jsp</value>    </property></bean>\n46'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 46, 'page_label': '47'}, page_content='World Before Spring Boot - 4 - NFRs\nLogging\nError Handling\nMonitoring\n<plugin>    <groupId>org.apache.tomcat.maven</groupId>    <artifactId>tomcat7-maven-plugin</artifactId>    <version>2.2</version>    <configuration>        <path>/</path>        <contextReloadable>true</contextReloadable>    </configuration></plugin>\n<dependency>    <groupId>log4j</groupId>    <artifactId>log4j</artifactId>    <version>1.2.17</version></dependency>\n47'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 47, 'page_label': '48'}, page_content='Setting up Spring Projects before Spring\nBoot was NOT easy!\n1: Dependency Management (pom.xml)\n2: Define Web App Configuration (web.xml)\n3: Manage Spring Beans (context.xml)\n4: Implement Non Functional Requirements (NFRs)\nAND repeat this for every new project!\nTypically takes a few days to setup for each\nproject (and countless hours to maintain)\nWorld Before Spring Boot!\n48'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 48, 'page_label': '49'}, page_content='Understanding Power of Spring Boot\n1: Create a Spring Boot Project\n2: Build a simple REST API using Spring Boot\n// http://localhost:8080/courses[  {    "id": 1,    "name": "Learn AWS",    "author": "in28minutes"  }]\n49'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 49, 'page_label': '50'}, page_content="Help you build PRODUCTION-READY apps QUICKLY\nBuild QUICKLY\nSpring Initializr\nSpring Boot Starter Projects\nSpring Boot Auto Configuration\nSpring Boot DevTools\nBe PRODUCTION-READY\nLogging\nDiﬀerent Configuration for Diﬀerent Environments\nProfiles, ConfigurationProperties\nMonitoring (Spring Boot Actuator)\n...\nWhat's the Most Important Goal of Spring Boot?\n50"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 50, 'page_label': '51'}, page_content='Spring Boot\nBUILD QUICKLY\n51'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 51, 'page_label': '52'}, page_content='I need a lot of frameworks to build application features:\nBuild a REST API: I need Spring, Spring MVC, Tomcat, JSON conversion...\nWrite Unit Tests: I need Spring Test, JUnit, Mockito, ...\nHow can I group them and make it easy to build applications?\nStarters: Convenient dependency descriptors for diﬀ. features\nSpring Boot provides variety of starter projects:\nWeb Application & REST API - Spring Boot Starter Web (spring-webmvc,\nspring-web, spring-boot-starter-tomcat, spring-boot-starter-json)\nUnit Tests - Spring Boot Starter Test\nTalk to database using JPA - Spring Boot Starter Data JPA\nTalk to database using JDBC - Spring Boot Starter JDBC\nSecure your web application or REST API - Spring Boot Starter Security\nExploring Spring Boot Starter Projects\n52'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 52, 'page_label': '53'}, page_content='I need lot of configuration to build Spring app:\nComponent Scan, DispatcherServlet, Data Sources, JSON Conversion, ...\nHow can I simplify this?\nAuto Configuration: Automated configuration for your app\nDecided based on:\nWhich frameworks are in the Class Path?\nWhat is the existing configuration (Annotations etc)?\nExample: Spring Boot Starter Web\nDispatcher Servlet (DispatcherServletAutoConfiguration)\nEmbedded Servlet Container - Tomcat is the default\n(EmbeddedWebServerFactoryCustomizerAutoConfiguration)\nDefault Error Pages (ErrorMvcAutoConfiguration)\nBean<->JSON\n(JacksonHttpMessageConvertersConfiguration)\nExploring Spring Boot Auto Configuration\n53'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 53, 'page_label': '54'}, page_content='Questions:\nWho is launching the Spring Context?\nWho is triggering the component scan?\nWho is enabling auto configuration?\nAnswer: @SpringBootApplication\n1: @SpringBootConfiguration: Indicates that a class provides Spring Boot\napplication @Configuration.\n2: @EnableAutoConfiguration: Enable auto-configuration of the Spring\nApplication Context,\n3: @ComponentScan: Enable component scan (for current package, by\ndefault)\nUnderstanding the Glue - @SpringBootApplication\n54'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 54, 'page_label': '55'}, page_content='Increase developer productivity\nWhy do you need to restart the server\nmanually for every code change?\nRemember: For pom.xml dependency\nchanges, you will need to restart server\nmanually\nBuild Faster with Spring Boot DevTools\n55'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 55, 'page_label': '56'}, page_content='Spring Boot\nPRODUCTION-READY\n56'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 56, 'page_label': '57'}, page_content='Applications have diﬀerent environments: Dev, QA,\nStage, Prod, ...\nDiﬀerent environments need diﬀerent configuration:\nDiﬀerent Databases\nDiﬀerent Web Services\nHow can you provide diﬀerent configuration for\ndiﬀerent environments?\nProfiles: Environment specific configuration\nHow can you define externalized configuration for\nyour application?\nConfigurationProperites: Define externalized configuration\nManaging App. Configuration using Profiles\n57'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 57, 'page_label': '58'}, page_content='How do you deploy your application?\nStep 1 : Install Java\nStep 2 : Install Web/Application Server\nTomcat/WebSphere/WebLogic etc\nStep 3 : Deploy the application WAR (Web ARchive)\nThis is the OLD WAR Approach\nComplex to setup!\nEmbedded Server - Simpler alternative\nStep 1 : Install Java\nStep 2 : Run JAR file\nMake JAR not WAR (Credit: Josh Long!)\nEmbedded Server Examples:\nspring-boot-starter-tomcat\nspring-boot-starter-jetty\nspring-boot-starter-undertow\nSimplify Deployment with Spring Boot Embedded Servers\n58'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 58, 'page_label': '59'}, page_content='Monitor and manage your application in your\nproduction\nProvides a number of endpoints:\nbeans - Complete list of Spring beans in your app\nhealth - Application health information\nmetrics - Application metrics\nmappings - Details around Request Mappings\nMonitor Applications using Spring Boot Actuator\n59'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 59, 'page_label': '60'}, page_content='Understanding Spring Boot vs Spring MVC vs Spring\nSpring Boot vs Spring MVC vs Spring: What\'s in it?\nSpring Framework: Dependency Injection\n@Component, @Autowired, Component Scan etc..\nJust Dependency Injection is NOT suﬀicient (You need other frameworks to build apps)\nSpring Modules and Spring Projects: Extend Spring Eco System\nProvide good integration with other frameworks (Hibernate/JPA, JUnit & Mockito for Unit Testing)\nSpring MVC (Spring Module): Simplify building web apps and REST API\nBuilding web applications with Struts was very complex\n@Controller, @RestController, @RequestMapping("/courses")\nSpring Boot (Spring Project): Build PRODUCTION-READY apps QUICKLY\nStarter Projects - Make it easy to build variety of applications\nAuto configuration - Eliminate configuration to setup Spring, Spring MVC and other frameworks!\nEnable non functional requirements (NFRs):\nActuator: Enables Advanced Monitoring of applications\nEmbedded Server: No need for separate application servers!\nLogging and Error Handling\nProfiles and ConfigurationProperties\n60'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 60, 'page_label': '61'}, page_content='Goal: 10,000 Feet overview of Spring Boot\nHelp you understand the terminology!\nStarter Projects\nAuto Configuration\nActuator\nDevTools\nAdvantages: Get started quickly with production ready\nfeatures!\nSpring Boot - Review\n61'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 61, 'page_label': '62'}, page_content='JPA and Hibernate\nin 10 Steps\n62'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 62, 'page_label': '63'}, page_content='Build a Simple JPA App using\nModern Spring Boot Approach\nGet Hands-on with JPA, Hibernate\nand Spring Boot\nWorld before JPA - JDBC, Spring JDBC\nWhy JPA? Why Hibernate? (JPA vs\nHibernate)\nWhy Spring Boot and Spring Boot Data\nJPA?\nJPA Terminology: Entity and Mapping\nGetting Started with JPA and Hibernate\n63'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 63, 'page_label': '64'}, page_content='01: Create a Spring Boot Project\nwith H2\n02: Create COURSE table\n03: Use Spring JDBC to play with\nCOURSE table\n04: Use JPA and Hibernate to play\nwith COURSE table\n05: Use Spring Data JPA to play\nwith COURSE table\nLearning JPA and Hibernate - Approach\n64'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 64, 'page_label': '65'}, page_content='We added Data JPA and H2 dependencies:\nSpring Boot Auto Configuration does some magic:\nInitialize JPA and Spring Data JPA frameworks\nLaunch an in memory database (H2)\nSetup connection from App to in-memory database\nLaunch a few scripts at startup (example: data.sql,\nschema.sql)\nRemember - H2 is in memory database\nDoes NOT persist data\nGreat for learning\nBUT NOT so great for production\nSpring Boot Auto Configuration Magic\n65'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 65, 'page_label': '66'}, page_content="JDBC\nWrite a lot of SQL queries! (delete from todo where id=?)\nAnd write a lot of Java code\nSpring JDBC\nWrite a lot of SQL queries (delete from todo where id=?)\nBUT lesser Java code\nJPA\nDo NOT worry about queries\nJust Map Entities to Tables!\nSpring Data JPA\nLet's make JPA even more simple!\nI will take care of everything!\nJDBC to Spring JDBC to JPA to Spring Data JPA\n66"),
# ...
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 204, 'page_label': '205'}, page_content='Regions - Advantages\nHigh Availability\nLow Latency\nGlobal Footprint\nAdhere to government regulations\n205'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 205, 'page_label': '206'}, page_content="Each AWS Region consists of multiple AZ's\nEach Availability Zone:\nCan have One or more discrete data centers\nhas independent & redundant power, networking &\nconnectivity\nAZs in a Region are connected through low-\nlatency links\n(Advantage) Increase availability and fault\ntolerance of applications in the same region\nAvailability Zones\n206"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 206, 'page_label': '207'}, page_content='Regions and Availability Zones examples\nRegion Code Region Availability Zones Availability Zones List\nus-east-1 US East (N. Virginia) 6 us-east-1a us-east-1b\nus-east-1c us-east-1d\nus-east-1e us-east-1f\neu-west-2 Europe (London) 3 eu-west-2a eu-west-2b\neu-west-2c\nap-south-1 Asia Pacific(Mumbai) 3 ap-south-1a ap-south-1b\nap-south-1c\nNew Regions and AZs are constantly added\n207'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 207, 'page_label': '208'}, page_content='EC2 Fundamentals\n208'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 208, 'page_label': '209'}, page_content='Introduction to EC2 (Elastic Compute Cloud)\n \nIn corporate data centers, applications are deployed to physical\nservers\nWhere do you deploy applications in the cloud?\nRent virtual machines\nEC2 instances - Virtual machines in AWS\nEC2 service - Provision EC2 instances or virtual machines\n209'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 209, 'page_label': '210'}, page_content='Understanding Important Features of EC2\n \n  \nCreate and manage lifecycle of EC2 instances\nAttach storage to your EC2 instances\nLoad balancing for multiple EC2 instances\nOur Goal: Play with EC2 instances!\n210'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 210, 'page_label': '211'}, page_content='Reviewing Important EC2 Concepts\nFeature Explanation\nAmazon Machine Image (AMI) What operating system and what so\x00ware do you want on the\ninstance?\nInstance Families Choose the right family of hardware (General purpose or\nCompute/Storage/Memory optimized or GPU)\nInstance Size (t2.nano,\nt2.micro,t2.small,t2.medium ...)\nChoose the right quantity of hardware (2 vCPUs, 4GB of memory)\nElastic Block Store Attach Disks to EC2 instances (Block Storage)\nSecurity Group Virtual firewall to control incoming and outgoing traﬀic to/from\nAWS resources (EC2 instances, databases etc)\nKey pair Public key and a private key\nPublic key is stored in EC2 instance\nPrivate key is stored by customer\n21 1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 211, 'page_label': '212'}, page_content='IAM: Identity and Access Management\nAuthentication (the right user?) and\nAuthorization (the right access?)\nRoot User: User we created our AWS account with\nCredentials: Email address and password\nDO NOT user Root User for day to day activities\nCreate a new IAM User and use the IAM user for regular activities\nThings we will do now:\n1: Create an IAM Group - Developers - with admin access\n2: Create an IAM user - in28minutes_dev - with group Developers\n3: Login with IAM user - in28minutes_dev\n(Remember) Bookmark Your Account Specific AWS URL\nIAM & Best Practices\n212'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 212, 'page_label': '213'}, page_content='With Great Power comes Great Responsibility\nCloud provides you with ability to create powerful resources\nHOWEVER its important to understand the associated costs\n5 Best Practices\n1: For the first week, monitor the billing dashboard everyday\n2: Set Budget Alerts\n1: Enable Billing Alerts - My Billing Dashboard > Billing preferences\n2: Create Budget Alert - Budgets > Create a Budget > Cost Budget > Alert\n3: STOP resources when you are not using them\n4: Understand FREE Tier and 12 Month Limits (HARD TO DO)\n5: Understand how pricing works for diﬀ. resources (HARD TO DO)\nCloud Best Practices - Managing Costs\n213'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 213, 'page_label': '214'}, page_content='Cloud Services\n214'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 214, 'page_label': '215'}, page_content="Do you want to continue running applications in\nthe cloud, the same way you run them in your data\ncenter?\nOR are there OTHER approaches?\nYou should understand some terminology:\nIaaS (Infrastructure as a Service)\nPaaS (Platform as a Service)\n....\nLet's get on a quick journey to understand these!\nCloud Services\n215"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 215, 'page_label': '216'}, page_content='Use only infrastructure from cloud provider\nEx: Using VM service to deploy your apps/databases\nCloud provider is responsible for:\nHardware, Networking & Virtualization\nYou are responsible for:\nOS upgrades and patches\nApplication Code and Runtime\nConfiguring load balancing\nAuto scaling\nAvailability\netc.. ( and a lot of things!)\nIAAS (Infrastructure as a Service)\n216'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 216, 'page_label': '217'}, page_content='Use a platform provided by the cloud\nCloud provider is responsible for:\nHardware, Networking & Virtualization\nOS (incl. upgrades and patches)\nApplication Runtime\nAuto scaling, Availability & Load balancing etc..\nYou are responsible for:\nConfiguration (of Application and Services)\nApplication code (if needed)\nExamples:\nCompute: AWS Elastic Beanstalk, Azure App Service, Google App\nEngine\nDatabases: Relational & NoSQL (Amazon RDS, Google Cloud\nSQL, Azure SQL Database etc)\nQueues, AI, ML, Operations etc!\nPAAS (Platform as a Service)\n217'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 217, 'page_label': '218'}, page_content='Simplest way to deploy and scale your web\napplications in AWS\nProvides end-to-end web application management\nSupports Java, .NET, Node.js, PHP, Ruby, Python, Go,\nand Docker applications\nNo usage charges - Pay for AWS resources\nprovisioned\nFeatures:\nAutomatic load balancing\nAuto scaling\nManaged platform updates\nAWS Elastic BeanStalk\n218'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 218, 'page_label': '219'}, page_content='Applications have millions of users:\nSame application is deployed to multiple VMs\nHow do you simplify creation and\nmanagement of multiple VMs?\nAuto Scaling Groups\nAllow you to create and manage a group of\nEC2 instances\nHow do you distribute traﬀic across\nmultiple EC2 instances?\nElastic Load Balancing\nAuto Scaling Group and Elastic Load Balancing\n219'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 219, 'page_label': '220'}, page_content='Microservices\nEnterprises are heading towards microservices architectures\nBuild small focused microservices\nFlexibility to innovate and build applications in diﬀerent programming languages (Go, Java,\nPython, JavaScript, etc)\nBUT deployments become complex!\nHow can we have one way of deploying Go, Java, Python or JavaScript ..\nmicroservices?\nEnter containers!\n220'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 220, 'page_label': '221'}, page_content='Create Docker images for each microservice\nDocker image has all needs of a microservice:\nApplication Runtime (JDK or Python or NodeJS)\nApplication code and Dependencies\nRuns the same way on any infrastructure:\nYour local machine, Corporate data center or in the Cloud\nAdvantages\nDocker is cloud neutral\nStandardization: Simplified Operations\nConsistent deployment, monitoring, logging ...\nDocker containers are light weight\nCompared to Virtual Machines as they do not have a Guest OS\nDocker provides isolation for containers\nContainers - Docker\n221'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 221, 'page_label': '222'}, page_content='Requirement : I want 10 instances of\nMicroservice A container, 15 instances\nof Microservice B container and ....\nTypical Features:\nAuto Scaling - Scale containers based on\ndemand\nService Discovery - Help microservices find\none another\nLoad Balancer - Distribute load among\nmultiple instances of a microservice\nSelf Healing - Do health checks and replace\nfailing instances\nZero Downtime Deployments - Release new\nversions without downtime\nContainer Orchestration\n222'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 222, 'page_label': '223'}, page_content='Cloud Neutral: Amazon EKS\nKubernetes: Open source container\norchestration\nManaged service: Amazon Elastic\nKubernetes Service\nEKS does not have a free tier\nAWS Specific: Amazon ECS\nAmazon Elastic Container Service\nFargate: Serverless ECS/EKS\nAWS Fargate does not have a free tier\nContainer Orchestration Options\n223'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 223, 'page_label': '224'}, page_content='What do we think about when we develop an application?\nWhere to deploy? What kind of server? What OS?\nHow do we take care of scaling and availability of the application?\nWhat if you don\'t worry about servers and focus ONLY on code?\nEnter Serverless\nRemember: Serverless does NOT mean "No Servers"\nServerless for me:\nYou don\'t worry about infrastructure (ZERO visibility into infrastructure)\nFlexible scaling and automated high availability\nMost Important: Pay for use\nIdeally ZERO REQUESTS => ZERO COST\nYou focus on code and the cloud managed service takes care of all\nthat is needed to scale your code to serve millions of requests!\nAnd you pay for requests and NOT servers!\nServerless\n224'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 224, 'page_label': '225'}, page_content="AWS Lambda\n \nTruly serverless\nYou don't worry about servers or scaling or availability\nYou only worry about your code\nYou pay for what you use\nNumber of requests\nDuration of requests\nMemory\n225"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 225, 'page_label': '226'}, page_content='AWS Lambda - Supported Languages\nJava\nGo\nPowerShell\nNode.js\nC#\nPython,\nRuby\nand a lot more...\n226'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 226, 'page_label': '227'}, page_content='Review - AWS Services for Compute\nAWS Service Name Description\nAmazon EC2 + ELB Traditional Approach (Virtual Servers + Load Balancing)\nUse when you need control over OS OR you want to run custom\nso\x00ware\nAWS Elastic Beanstalk Simplify management of web applications and batch\napplications\nAutomatically creates EC2 + ELB(load balancing and auto\nscaling)\nAmazon Elastic Container Service (Amazon\nECS)\nSimplify running of microservices with Docker containers\nRun containers in EC2 based ECS Clusters\nAmazon Elastic Kubernetes Service\n(Amazon EKS)\nRun and scale Kubernetes clusters\nAWS Fargate Serverless version of ECS and EKS\nAWS Lambda Serverless - Do NOT worry about servers\n227'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 227, 'page_label': '228'}, page_content='You are all set!\n228'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 228, 'page_label': '229'}, page_content="You have a lot of patience!\nCongratulations\nYou have put your best foot\nforward to be a great\ndeveloper!\nDon't stop your learning\njourney!\nKeep Learning Every Day!\nGood Luck!\nLet's clap for you!\n229"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 229, 'page_label': '230'}, page_content='Recommend the course to\nyour friends!\nDo not forget to review!\nYour Success = My Success\nShare your success story with\nme on LinkedIn (Ranga\nKaranam)\nShare your success story and\nlessons learnt in Q&A with\nother learners!\nDo Not Forget!\n230'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 230, 'page_label': '231'}, page_content='231')]

# %%
def text_extract(pdf:list) -> str:
    """
        Extracts the full text of loaded pdf
    """
    full_text = "\n".join([doc.page_content for doc in pdf])
    return full_text

# %%
extracted_text = text_extract(pdf)
extracted_text
# Out:
# 'Master Spring & Spring Boot\nwith Hibernate & React\n1\nTop frameworks in the Java world today\nSpring Framework\nSpring Boot\nBeginners find the first steps very diﬀicult:\nLot of terminology: Dependency Injection, IOC, Auto\nwiring, Auto configuration, Starter Projects ..\nVariety of applications: Web app, REST API, Full Stack\nVariety of other framework, tool and platform\nintegrations: Maven, Gradle, Spring Data, JPA, Hibernate,\nDocker and Cloud\nGetting Started\n2\nWe\'ve created a simple path focusing on the\nFundamentals\nUsing a Hands-on Approach\nYou will build more than 10 Maven and Gradle\nprojects during this course!\nThis course is designed for absolute beginners to\nSpring & Spring Boot\nOur Goal : Help you start your journey with Spring &\nSpring Boot\nSimple Path - Learn Spring & Spring Boot & ...\n3\nLearning Spring & Spring Boot\ncan be tricky:\nLots of new terminology, tools and\nframeworks\nAs time passes, we forget things\nHow do you improve your\nchances of remembering\nthings?\nActive learning - think & make notes\nReview the presentation once in a\nwhile\nHow do you put your best foot forward?\n4\nVideos with:\nPresentations &\nDemos where we build projects\nQuizzes:\nTo Reinforce Concepts\n(Recommended) Take your\ntime. Do not hesitate to\nreplay videos!\n(Recommended) Have Fun!\nOur Approach\n5\n6\nSpring Framework\n7\nYou can build a variety of applications using\nJava, Spring and Spring Boot:\nWeb\nREST API\nFull Stack\nMicroservices\nIrrespective of the app you are building:\nSpring framework provides all the core features\nUnderstanding Spring helps you learn Spring Boot easily\nHelps in debugging problems quickly\nIn this module, we focus extensively on Spring\nFramework\nGetting Started with Spring Framework - Why?\n8\nGoal: Understand core features of Spring Framework\nApproach: Build a Loose Coupled Hello World Gaming\nApp with Modern Spring Approach\nGet Hands-on with Spring and understand:\nWhy Spring?\nTerminology\nTight Coupling and Loose Coupling\nIOC Container\nApplication Context\nComponent Scan\nDependency Injection\nSpring Beans\nAuto Wiring\nGetting Started with Spring Framework - Goals\n9\nDesign Game Runner to run games (Mario, SuperContra,\nPacman etc) in an iterative approach:\nIteration 1: Tightly Coupled Java Code\nGameRunner class\nGame classes: Mario, SuperContra, Pacman etc\nIteration 2: Loose Coupling - Interfaces\nGameRunner class\nGamingConsole interface\nGame classes: Mario, SuperContra, Pacman etc\nIteration 3: Loose Coupling - Spring Level 1\nSpring Beans\nSpring framework will manage objects and wiring\nIteration 4: Loose Coupling - Spring Level 2\nSpring Annotations\nSpring framework will create, manage & auto-wire objects\n...\nGetting Started with Spring Framework - Approach\n10\nVery Few Spring Framework users understand\nfundamentals:\nSpring Container vs Spring Context vs IOC Container vs\nApplication Context\nJava Bean vs Spring Bean\nAuto Wiring vs Dependency Injection\nHow can you build loosely coupled applications?\nMaking good use of Java Interfaces along with Spring\nWe spent multiple weeks designing this section to\nhelp you understand these fundamentals\nThis is the most important section of the course:\nFocus really well to understand the fundamentals\nGood luck!\nDo you want to do well at interviews?\n1 1\nLocal Variable Type Inference\nJava compiler infers the type of the variable at compile time\nIntroduced in Java 10\nYou can add final if you want\nvar can also be used in loops\nRemember:\nYou cannot assign null\nvar is NOT a keyword\nCANNOT be used for member variables, method parameters or return types\nBest Practices:\nGood variable names\nMinimizeScope\n// List<String> numbers = new ArrayList<>(list);var numbers = new ArrayList<>(list);\n12\nCoupling: How much work is involved in changing something?\nCoupling is important everywhere:\nAn engine is tightly coupled to a Car\nA wheel is loosely coupled to a Car\nYou can take a laptop anywhere you ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_pdf(pdf:list) -> list:
    """
        Splits the pdf loaded list into chunks
    """
    splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
    splitted_text = splitter.split_documents(pdf)
    return splitted_text

# %%
splitted_text = split_pdf(pdf)

# %%
splitted_text
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 0, 'page_label': '1'}, page_content='Master Spring & Spring Boot\nwith Hibernate & React\n1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Top frameworks in the Java world today\nSpring Framework\nSpring Boot'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Spring Boot\nBeginners find the first steps very diﬀicult:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Lot of terminology: Dependency Injection, IOC, Auto\nwiring, Auto configuration, Starter Projects ..'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Variety of applications: Web app, REST API, Full Stack'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='Variety of other framework, tool and platform'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 1, 'page_label': '2'}, page_content='integrations: Maven, Gradle, Spring Data, JPA, Hibernate,\nDocker and Cloud\nGetting Started\n2'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content="We've created a simple path focusing on the\nFundamentals\nUsing a Hands-on Approach"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content='You will build more than 10 Maven and Gradle\nprojects during this course!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content='This course is designed for absolute beginners to\nSpring & Spring Boot'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content='Our Goal : Help you start your journey with Spring &\nSpring Boot'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 2, 'page_label': '3'}, page_content='Spring Boot\nSimple Path - Learn Spring & Spring Boot & ...\n3'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 3, 'page_label': '4'}, page_content='Learning Spring & Spring Boot\ncan be tricky:\nLots of new terminology, tools and\nframeworks'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 3, 'page_label': '4'}, page_content='frameworks\nAs time passes, we forget things\nHow do you improve your\nchances of remembering\nthings?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 3, 'page_label': '4'}, page_content='things?\nActive learning - think & make notes\nReview the presentation once in a\nwhile'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 3, 'page_label': '4'}, page_content='while\nHow do you put your best foot forward?\n4'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 4, 'page_label': '5'}, page_content='Videos with:\nPresentations &\nDemos where we build projects\nQuizzes:\nTo Reinforce Concepts'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 4, 'page_label': '5'}, page_content='(Recommended) Take your\ntime. Do not hesitate to\nreplay videos!\n(Recommended) Have Fun!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 4, 'page_label': '5'}, page_content='Our Approach\n5'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 5, 'page_label': '6'}, page_content='6'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 6, 'page_label': '7'}, page_content='Spring Framework\n7'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='You can build a variety of applications using\nJava, Spring and Spring Boot:\nWeb\nREST API\nFull Stack'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='REST API\nFull Stack\nMicroservices\nIrrespective of the app you are building:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='Spring framework provides all the core features'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='Understanding Spring helps you learn Spring Boot easily\nHelps in debugging problems quickly'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='In this module, we focus extensively on Spring\nFramework'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 7, 'page_label': '8'}, page_content='Framework\nGetting Started with Spring Framework - Why?\n8'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='Goal: Understand core features of Spring Framework'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='Approach: Build a Loose Coupled Hello World Gaming\nApp with Modern Spring Approach'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='Get Hands-on with Spring and understand:\nWhy Spring?\nTerminology\nTight Coupling and Loose Coupling'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='IOC Container\nApplication Context\nComponent Scan\nDependency Injection\nSpring Beans\nAuto Wiring'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 8, 'page_label': '9'}, page_content='Auto Wiring\nGetting Started with Spring Framework - Goals\n9'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Design Game Runner to run games (Mario, SuperContra,\nPacman etc) in an iterative approach:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Iteration 1: Tightly Coupled Java Code\nGameRunner class'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='GameRunner class\nGame classes: Mario, SuperContra, Pacman etc'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Iteration 2: Loose Coupling - Interfaces\nGameRunner class\nGamingConsole interface'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Game classes: Mario, SuperContra, Pacman etc\nIteration 3: Loose Coupling - Spring Level 1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Spring Beans\nSpring framework will manage objects and wiring'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Iteration 4: Loose Coupling - Spring Level 2\nSpring Annotations'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='Spring Annotations\nSpring framework will create, manage & auto-wire objects\n...'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 9, 'page_label': '10'}, page_content='...\nGetting Started with Spring Framework - Approach\n10'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='Very Few Spring Framework users understand\nfundamentals:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='fundamentals:\nSpring Container vs Spring Context vs IOC Container vs\nApplication Context'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='Application Context\nJava Bean vs Spring Bean\nAuto Wiring vs Dependency Injection'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='How can you build loosely coupled applications?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='Making good use of Java Interfaces along with Spring'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='We spent multiple weeks designing this section to\nhelp you understand these fundamentals'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='This is the most important section of the course:\nFocus really well to understand the fundamentals'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 10, 'page_label': '11'}, page_content='Good luck!\nDo you want to do well at interviews?\n1 1'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='Local Variable Type Inference\nJava compiler infers the type of the variable at compile time'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='Introduced in Java 10\nYou can add final if you want\nvar can also be used in loops\nRemember:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='Remember:\nYou cannot assign null\nvar is NOT a keyword'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='CANNOT be used for member variables, method parameters or return types\nBest Practices:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='Best Practices:\nGood variable names\nMinimizeScope'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='MinimizeScope\n// List<String> numbers = new ArrayList<>(list);var numbers = new ArrayList<>(list);'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 11, 'page_label': '12'}, page_content='12'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='Coupling: How much work is involved in changing something?\nCoupling is important everywhere:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='An engine is tightly coupled to a Car\nA wheel is loosely coupled to a Car'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='You can take a laptop anywhere you go'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='A computer, on the other hand, is a little bit more diﬀicult to move'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='Coupling is even more important in building great so\x00ware'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='Only thing constant in technology is change\nBusiness requirements change\nFrameworks change'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='Frameworks change\nCode changes\nWe want Loose Coupling as much as possible'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='We want to make functional changes with as less code changes as possible'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content="Let's explore how Java Interfaces and Spring Framework help\nwith Loose Coupling!"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 12, 'page_label': '13'}, page_content='Why is Coupling Important?\n13'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content='Question 1: Spring Container vs Spring Context vs IOC\nContainer vs Application Context'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content='Question 2: Java Bean vs Spring Bean\nQuestion 3: How can I list all beans managed by'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content='Spring Framework?\nQuestion 4: What if multiple matching beans are\navailable?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content='available?\nQuestion 5: Spring is managing objects and\nperforming auto-wiring.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content="BUT aren't we writing the code to create objects?\nHow do we get Spring to create objects for us?"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 13, 'page_label': '14'}, page_content='Question 6: Is Spring really making things easy?\nSpring Questions You Might Be Thinking About\n14'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='Spring Container: Manages Spring beans &\ntheir lifecycle\n1: Bean Factory: Basic Spring Container'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='2: Application Context: Advanced Spring\nContainer with enterprise-specific features'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='Easy to use in web applications\nEasy internationalization\nEasy integration with Spring AOP'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='Which one to use?: Most enterprise\napplications use Application Context'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='Recommended for web applications, web services -\nREST API and microservices'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 14, 'page_label': '15'}, page_content='What is Spring Container?\n15'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='Java Bean: Classes adhering to 3 constraints:\n1: Have public default (no argument) constructors'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='2: Allow access to their properties using getter and\nsetter methods'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='setter methods\n3: Implement java.io.Serializable\nPOJO: Plain Old Java Object\nNo constraints'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='No constraints\nAny Java Object is a POJO!\nSpring Bean: Any Java object that is managed\nby Spring'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='by Spring\nSpring uses IOC Container (Bean Factory or\nApplication Context) to manage these objects'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 15, 'page_label': '16'}, page_content='Exploring Java Bean vs POJO vs Spring Bean\n16'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Constructor-based : Dependencies are set\nby creating the Bean using its Constructor'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Setter-based : Dependencies are set by\ncalling setter methods on your beans'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Field: No setter or constructor.\nDependency is injected using reflection.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Question: Which one should you use?\nSpring team recommends Constructor-based'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='injection as dependencies are automatically set\nwhen an object is created!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 16, 'page_label': '17'}, page_content='Exploring Spring - Dependency Injection Types\n17'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='When a dependency needs to be @Autowired, IOC container'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='looks for matches/candidates (by name and/or type)\n1: If no match is found'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='Result: Exception is thrown\nYou need to help Spring Framework find a match\nTypical problems:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='Typical problems:\n@Component (or ..) missing\nClass not in component scan\n2: One match is found'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='Result: Autowiring is successful\n3: Multiple candidates\nResult: Exception is thrown'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='You need to help Spring Framework choose between the candidates\n1: Mark one of them as @Primary'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='If only one of the candidates is marked @Primary, it becomes the auto-wired value'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='2: Use @Qualifier - Example: @Qualifier("myQualifierName")\nProvides more specific control'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 17, 'page_label': '18'}, page_content='Can be used on a class, member variables and method parameters\nExploring auto-wiring in depth\n18'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Primary vs @Qualifier - Which one to use?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Primary - A bean should be given preference when multiple candidates are qualified'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Qualifier - A specific bean should be auto-wired (name of the bean can be used as qualifier)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='ALWAYS think from the perspective of the class using the SortingAlgorithm:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='1: Just @Autowired: Give me (preferred) SortingAlgorithm'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='2: @Autowired + @Qualifier: I only want to use specific SortingAlgorithm - RadixSort'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='(REMEMBER) @Qualifier has higher priority then @Primary'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Component @Primaryclass QuickSort implement SortingAlgorithm {}'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Componentclass BubbleSort implement SortingAlgorithm {}'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Component @Qualifier("RadixSortQualifier")class RadixSort implement SortingAlgorithm {}'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Componentclass ComplexAlgorithm    @Autowired     private SortingAlgorithm algorithm;'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='@Componentclass AnotherComplexAlgorithm    @Autowired @Qualifier("RadixSortQualifier")     private'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='private SortingAlgorithm iWantToUseRadixSortOnly;'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 18, 'page_label': '19'}, page_content='19'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='@Component (..): An instance of class will be managed by\nSpring framework'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Spring framework\nDependency: GameRunner needs GamingConsole impl!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='GamingConsole Impl (Ex: MarioGame) is a dependency of GameRunner'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Component Scan: How does Spring Framework find\ncomponent classes?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='component classes?\nIt scans packages! (@ComponentScan("com.in28minutes"))'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Dependency Injection: Identify beans, their dependencies'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='and wire them together (provides IOC - Inversion of Control)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Spring Beans: An object managed by Spring Framework'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='IoC container: Manages the lifecycle of beans and dependencies'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Types: ApplicationContext (complex), BeanFactory (simpler features - rarely used)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Autowiring: Process of wiring in dependencies for a Spring Bean'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 19, 'page_label': '20'}, page_content='Spring Framework - Important Terminology\n20'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='@Component vs @Bean\nHeading @Component @Bean'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Where? Can be used on any Java class Typically used on methods in Spring\nConfiguration classes'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Ease of use Very easy. Just add an annotation. You write all the code.'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Autowiring Yes - Field, Setter or Constructor Injection Yes - method call or method parameters'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Who creates\nbeans?\nSpring Framework You write bean creation code\nRecommended\nFor'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Recommended\nFor\nInstantiating Beans for Your Own Application\nCode: @Component'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Code: @Component\n1:Custom Business Logic\n2: Instantiating Beans for 3rd-party\nlibraries: @Bean'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='Beans per class? One (Singleton) or Many (Prototype) One or Many - You can create as many as'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 20, 'page_label': '21'}, page_content='you want\n21'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='-\nIn Game Runner Hello World App, we have very few classes'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='BUT Real World applications are much more complex:\nMultiple Layers (Web, Business, Data etc)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Each layer is dependent on the layer below it!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Example: Business Layer class talks to a Data Layer class'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Data Layer class is a dependency of Business Layer class'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='There are thousands of such dependencies in every application!\nWith Spring Framework:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='INSTEAD of FOCUSING on objects, their dependencies and wiring'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='You can focus on the business logic of your application!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Spring Framework manages the lifecycle of objects:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Mark components using annotations: @Component (and others..)\nMark dependencies using @Autowired'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Allow Spring Framework to do its magic!\nEx: BusinessCalculationService'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 21, 'page_label': '22'}, page_content='Why do we have a lot of Dependencies?\n22'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='Create classes and interfaces as needed\nUse constructor injection to inject dependencies'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='Make MongoDbDataService as primary\nCreate a Spring Context\nPrefer annotations'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='Prefer annotations\nRetrieve BusinessCalculationService bean and run findMax method'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='Exercise - BusinessCalculationService\npublic interface DataService    int[] retrieveData();'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='public class MongoDbDataService implements DataService    public int[] retrieveData()        return'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 22, 'page_label': '23'}, page_content='return new int[] { 11, 22, 33, 44, 55 };'),
# ...
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='2: Create RSA Key object using Key Pair\ncom.nimbusds.jose.jwk.RSAKey'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='3: Create JWKSource (JSON Web Key source)\nCreate JWKSet (a new JSON Web Key set) with the RSA Key'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='Create JWKSource using the JWKSet\n4: Use RSA Public Key for Decoding'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='NimbusJwtDecoder.withPublicKey(rsaKey().toRSAPublicKey()).build()\n5: Use JWKSource for Encoding'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='return new NimbusJwtEncoder(jwkSource());\nWe will use this later in the JWT Resource'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 155, 'page_label': '156'}, page_content='Getting Started with JWT Security Configuration\n156'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 156, 'page_label': '157'}, page_content='Getting Started with JWT Resource\nStep 1: Use Basic Auth for getting the JWT Token'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 156, 'page_label': '157'}, page_content='Step 2-n: Use JWT token as Bearer Token for authenticating requests'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 156, 'page_label': '157'}, page_content='username:"in28minutes",password:"dummy"\nResponse{"token": "TOKEN_VALUE"}\n157'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='Authentication is done as part of the Spring Security Filter\nChain!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='Chain!\n1: AuthenticationManager - Responsible for authentication'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='Can interact with multiple authentication providers'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='2: AuthenticationProvider - Perform specific authentication\ntype'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='type\nJwtAuthenticationProvider - JWT Authentication'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='3: UserDetailsService - Core interface to load user data\nHow is authentication result stored?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='SecurityContextHolder > SecurityContext > Authentication >\nGrantedAuthority'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='GrantedAuthority\nAuthentication - (A\x00er authentication) Holds user (Principal) details'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='GrantedAuthority - An authority granted to principal (roles, scopes,..)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 157, 'page_label': '158'}, page_content='Understanding Spring Security Authentication\n158'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='1: Global Security: authorizeHttpRequests\n.requestMatchers("/users").hasRole("USER")'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='hasRole, hasAuthority, hasAnyAuthority, isAuthenticated\n2: Method Security (@EnableMethodSecurity)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='@Pre and @Post Annotations\n@PreAuthorize("hasRole(\'USER\') and #username == authentication.name")'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='@PostAuthorize("returnObject.username == \'in28minutes\'")\nJSR-250 annotations'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='JSR-250 annotations\n@EnableMethodSecurity(jsr250Enabled = true)\n@RolesAllowed({"ADMIN", "USER"})'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content='@Secured annotation\n@EnableMethodSecurity(securedEnabled = true)\n@Secured({"ADMIN", "USER"})'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 158, 'page_label': '159'}, page_content="(REMEMBER) JWT: Use\nhasAuthority('SCOPEROLEUSER')\nExploring Spring Security Authorization\n159"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='How can you give an application access to files\npresent on your google drive?'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content="You don't want to provide your credentials (NOT SECURE)"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='OAuth: Industry-standard protocol for authorization\nAlso supports authentication now!'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content="Let's say you want to provide access to your Google\nDrive files to the Todo management application!"),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='Important Concepts:\nResource owner: You (Person owning the google drive files)'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='Client application: Todo management application'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='Resource server: Contains the resources that are being accessed - Google\nDrive'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 159, 'page_label': '160'}, page_content='Drive\nAuthorization server: Google OAuth Server\nGetting Started with OAuth\n160'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 160, 'page_label': '161'}, page_content='Spring AOP\n161'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='A layered approach is typically used to build applications:'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='Web Layer - View logic for web apps OR JSON conversion for REST API\nBusiness Layer - Business Logic'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='Data Layer - Persistence Logic\nEach layer has diﬀerent responsibilities'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='HOWEVER, there are a few common aspects that apply to all layers\nSecurity\nPerformance\nLogging'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='Performance\nLogging\nThese common aspects are called Cross Cutting Concerns'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='Aspect Oriented Programming can be used to implement Cross Cutting\nConcerns'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 161, 'page_label': '162'}, page_content='Concerns\nWhat is Aspect Oriented Programming?\n162'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='1: Implement the cross cutting concern as an aspect'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='2: Define point cuts to indicate where the aspect should be\napplied\nTWO Popular AOP Frameworks'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='Spring AOP\nNOT a complete AOP solution BUT very popular\nOnly works with Spring Beans'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='Example: Intercept method calls to Spring Beans\nAspectJ\nComplete AOP solution BUT rarely used'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='Example: Intercept any method call on any Java class\nExample: Intercept change of values in a field'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 162, 'page_label': '163'}, page_content='We will be focusing on Spring AOP in this section\nWhat is Aspect Oriented Programming? - 2\n163'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'creationdate': '2024-09-05T04:52:38+00:00', 'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'page': 163, 'page_label': '164'}, page_content='Compile Time\nAdvice - What code to execute?\nExample: Logging, Authentication'),
#  ...]

# %%
from langchain_community.vectorstores import Chroma
import os
from langchain_huggingface import HuggingFaceEmbeddings

os.environ['HF_HOME'] = 'C:/Users/Aditya/Desktop/Langchain/Langchain_Models/LOCALINSTALLEDMODELS'

embedding_model =  HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
PERSIST_DIR = "./chroma_persist"
CHROMA_COLLECTION_NAME = "pdf_docs"

def embed_pdf(splitted_text:list)->Chroma:
    """
        Embedds the chunks into vectors and store in vector space
        Returns Vector Embeddings
    """
     
    if os.path.exists(PERSIST_DIR) and os.listdir(PERSIST_DIR):
        vectordb = Chroma(
            persist_directory=PERSIST_DIR,
            embedding_function=embedding_model,
            collection_name=CHROMA_COLLECTION_NAME
        )
    else:
        vectordb = Chroma.from_documents(
            splitted_text,
            embedding_model,
            persist_directory=PERSIST_DIR,
            collection_name=CHROMA_COLLECTION_NAME
        )
        vectordb.persist()

    return vectordb

# %%
vectordb = embed_pdf(splitted_text)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_12904\1829947926.py:30: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectordb.persist()

# %%
def get_similar_pages(user_query:str,vectordb:Chroma)->list:
    vectordb_retriever = vectordb.as_retriever(search_type="mmr", search_kwargs={"k": 5})
    similar_pages = vectordb_retriever.get_relevant_documents(user_query)
    return similar_pages

# %%
similar_pages = get_similar_pages("What is hibernate",vectordb)
similar_pages
# Out:
# [Document(metadata={'creationdate': '2024-09-05T04:52:38+00:00', 'source': 'sp.pdf', 'creator': 'Decktape', 'moddate': '2024-09-11T16:38:45+00:00', 'producer': 'iLovePDF', 'page': 68, 'page_label': '69', 'total_pages': 231}, page_content='Who manages the entities?\nHibernate is one of the popular\nimplementations of JPA'),
#  Document(metadata={'moddate': '2024-09-11T16:38:45+00:00', 'source': 'sp.pdf', 'total_pages': 231, 'creator': 'Decktape', 'producer': 'iLovePDF', 'creationdate': '2024-09-05T04:52:38+00:00', 'page_label': '69', 'page': 68}, page_content='Using Hibernate directly would result in a\nlock in to Hibernate'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Decktape', 'moddate': '2024-09-11T16:38:45+00:00', 'page_label': '64', 'creationdate': '2024-09-05T04:52:38+00:00', 'page': 63, 'source': 'sp.pdf', 'total_pages': 231}, page_content='COURSE table\n04: Use JPA and Hibernate to play\nwith COURSE table\n05: Use Spring Data JPA to play'),
#  Document(metadata={'page_label': '1', 'page': 0, 'creator': 'Decktape', 'moddate': '2024-09-11T16:38:45+00:00', 'total_pages': 231, 'source': 'sp.pdf', 'producer': 'iLovePDF', 'creationdate': '2024-09-05T04:52:38+00:00'}, page_content='Master Spring & Spring Boot\nwith Hibernate & React\n1'),
#  Document(metadata={'page_label': '32', 'source': 'sp.pdf', 'moddate': '2024-09-11T16:38:45+00:00', 'creationdate': '2024-09-05T04:52:38+00:00', 'page': 31, 'creator': 'Decktape', 'total_pages': 231, 'producer': 'iLovePDF'}, page_content='@Bean Indicates that a method produces a bean to be managed by the Spring container')]

# %%
from langchain_core.tools import tool

def answer_question_on_query(similar_pages:list,user_query:str):
    """
    Answer a question based on input text from the vector store.
    Retrievers similar pages from store and gives answer
    """
    question = user_query

    prompt = f"Answer the question using the following context:\n\n{similar_pages}\n\nQuestion: {question} also add your suggestions in the answer if lack of context"
    return chat_model.invoke(prompt).content

# %%
answer_question_on_query(similar_pages,"what is hibernate")

# %%
from langchain_core.tools import tool

def summarize_on_topic(similar_pages:list,topic:str):
    """
    Answer a question based on input text from the vector store.
    Retrievers similar pages from store and gives answer
    """

    prompt = f"Summarize the following content in detail:\n\n{topic} using the following context:\n\n {similar_pages} also add your suggestions in the summary if lack of context"
    return chat_model.invoke(prompt).content

# %%
summarize_on_topic(similar_pages,"Hibernate")

# %%
def generate_quiz_on_topic(similar_pages:list,user_query:str):
    """
    Generate a 10-question quiz from text 
    Returns a set of 10 questions with answers
    """
    prompt = f"Based on the following content {similar_pages}, create a quiz of 10 questions with answers at the end:\n\n{user_query} also add your suggestions in the quiz if lack of context"
    return chat_model.invoke(prompt).content

# %%
generate_quiz_on_topic(similar_pages,"Hibernate")

# %%
def summarize_text(extracted_text:str):
    """
    Summarize text tool
    Returns Summary of provided Chunks
    """
    prompt = f"Summarize the following content in detail:\n\n{extracted_text}"
    return chat_model.invoke(prompt).content

# %%
summarize_text(extracted_text)

# %%
def generate_quiz(extracted_text: str):
    """
    Generate a 10-question quiz from text 
    Returns a set of 10 questions with answers
    """
    prompt = (
        "Based on the following content, create a quiz of 10 questions "
        "with answers at the end:\n\n"
        f"{extracted_text}"
    )
    return chat_model.invoke(prompt).content

# %%
generate_quiz(extracted_text)
